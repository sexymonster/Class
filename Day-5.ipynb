# %%
# datetime : 날짜, 시간 관련 모듈
import datetime as dt

print("현재시각 출력",dt.datetime.now())
# Out:
# 현재시각 출력 2022-05-04 09:46:56.514653

# %%
now = dt.datetime.now()
print(now.year,"년")
print(now.month,"월")
print(now.day,"일")
print(now.hour,"시")
print(now.minute,"분")
print(now.year,"년",now.month,"월",now.day,"일",now.hour,"시",now.minute,"분")
# Out:
# 2022 년
# 5 월
# 4 일
# 9 시
# 51 분
# 2022 년 5 월 4 일 9 시 51 분

# %%
import time

target = time.time() + 3
while time.time() < target:
    print("대기상태", time.time())
# time.sleep(3)
# Out:
# 대기상태 1651625871.5745132
# 대기상태 1651625871.5745132
# 대기상태 1651625871.5745132
# 대기상태 1651625871.5745132
# 대기상태 1651625871.5745132
# 대기상태 1651625871.575522
# 대기상태 1651625871.575522
# 대기상태 1651625871.5765114
# 대기상태 1651625871.5765114
# 대기상태 1651625871.579513
# 대기상태 1651625871.579513
# 대기상태 1651625871.579513
# 대기상태 1651625871.579513
# 대기상태 1651625871.579513
# 대기상태 1651625871.580512
# 대기상태 1651625871.5825093
# 대기상태 1651625871.5825093
# 대기상태 1651625871.5825093
# 대기상태 1651625871.5825093
# 대기상태 1651625871.5825093
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# 대기상태 1651625871.5835118
# ...

# %%
# urllib 모듈 : 웹의 데이터 연결
from urllib import request

target = request.urlopen("http://google.com")
print(target.read()) #<html> tag 형식으로 변경
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="jnu9z2bncyT-lLlcpZLNQg">(function(){window.google={kEI:\'MtVxYsoOjqCYBbrch_AM\',kEXPI:\'0,1302536,56873,6059,206,4804,926,1390,383,246,5,1354,4013,1238,1122515,1197778,380713,16111,28687,17572,4859,1361,284,9007,3028,17580,4020,978,13228,3847,4192,6430,22112,629,5081,887,706,1279,2742,149,1103,840,6297,3514,606,2023,1777,520,14670,3227,2845,7,17450,7540,4085,4695,1851,2614,13142,3,346,230,6460,148,12314,1661,4,1528,655,1649,7039,25073,2658,7356,9816,3843,4437,16786,5797,2560,4094,4052,3,3541,1,11943,30211,2,14022,1931,5589,744,5852,9865,1758,5679,1020,2379,2721,18260,2,6,7754,4569,6252,6723,16699,1254,5835,12137,2831,1554,2778,19,3026,3044,1395,445,2,2,1,24778,1417,1,436,8155,2566,3829,187,799,189,1291,
# ...

# %%
# !pip install beautifulsoup4
# Out:
# ...
# WARNING: Ignoring invalid distribution -eautifulsoup4 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eautifulsoup4 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eautifulsoup4 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eautifulsoup4 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eautifulsoup4 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eautifulsoup4 (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -eautifulsoup4 (c:\programdata\anaconda3\lib\site-packages)

# %%
# url 데이터 다루기 위해 bs4의 BeautifulSoup 을 import
from bs4 import BeautifulSoup

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
html_doc
# Out:
# '<html><head><title>The Dormouse\'s story</title></head>\n<body>\n<p class="title"><b>The Dormouse\'s story</b></p>\n\n<p class="story">Once upon a time there were three little sisters; and their names were\n<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,\n<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and\n<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;\nand they lived at the bottom of a well.</p>\n\n<p class="story">...</p>\n'

# %%
soup = BeautifulSoup(html_doc, "html.parser") ###

# %%
soup
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
# 각 tag 의 데이터 검색
print(soup.title)
print(soup.title.name) # tag의 이름
print(soup.title.parent) # 부모(앞)의 tag
print(soup.title.parent.name) # 부모(앞)의 tag의 이름
print(soup.title.string) # title의 데이터
# Out:
# <title>The Dormouse's story</title>
# title
# <head><title>The Dormouse's story</title></head>
# head
# The Dormouse's story

# %%
print(soup.p)
print(soup.p["class"]) #하나만 검색
print()
# 모든 p 태그 검색
print(soup.find_all('p')) # 'p' 태그 검색 후 리스트로 반환
print()
print(soup.find('a')) # 처음 나오는 a 태그 하나만 검색
print()
# id="link2" 를 검색
print(soup.find(id="link2"))
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
# ['title']
#
# [<p class="title"><b>The Dormouse's story</b></p>, <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>, <p class="story">...</p>]
#
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
#
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>

# %%
for link in soup.find_all('a'):
    print(link.get("href"))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
soup.get_text()
# Out:
# "The Dormouse's story\n\nThe Dormouse's story\nOnce upon a time there were three little sisters; and their names were\nElsie,\nLacie and\nTillie;\nand they lived at the bottom of a well.\n...\n"

# %%
tag = BeautifulSoup('<b id="boldest">bold</b>', 'html.parser').b
tag['id']
# Out:
# 'boldest'

# %%
tag.attrs
# Out:
# {'id': 'boldest'}

# %%
tag["another-attribute"] = 1
tag.attrs
# Out:
# {'id': 'boldest', 'another-attribute': 1}

# %%
# 웹 프레임워크 : flask

# %%
import test_package.module_a as a
import test_package.module_b as b

# %%
print(a.variable_a, b.variable_b)
# Out:
# 모든 a의 변수 모든 b의 변수

# %%
from test_package import module_a, module_b

# %%
module_a.variable_a
# Out:
# '모든 a의 변수'

# %%
# __init__.py -> __all__ =[모든 모듈명]
from test_package import *

# %%
module_a.variable_a
# Out:
# 'a 모듈의 변수'

# %%
module_b.variable_b
# Out:
# 'b 모듈의 변수'

# %%
# 학생 리스트를 선언합니다.
students = [
    {"name": "윤인성", "korean":87, "math":98,"english":88,"science":95},
    {"name": "연하진", "korean":92, "math":98,"english":96,"science":98},
    {"name": "구지연", "korean":76, "math":96,"english":94,"science":90},
    {"name": "나선주", "korean":98, "math":92,"english":96,"science":92},
    {"name": "윤아린", "korean":95, "math":98,"english":98,"science":98},
    {"name": "윤명월", "korean":64, "math":88,"english":92,"science":92}
] 
# 학생을 한 명씩 반복합니다.
print("이름","총점","평균",sep="\t")
for student in students:
    score_sum = student["korean"]+student["math"]+student["english"]+\
    student["science"]
    score_avg = score_sum / 4
    print(student["name"],score_sum,score_avg,sep="\t")
# Out:
# 이름	총점	평균
# 윤인성	368	92.0
# 연하진	384	96.0
# 구지연	356	89.0
# 나선주	378	94.5
# 윤아린	389	97.25
# 윤명월	336	84.0

# %%
class Student:
#     def __init__(self, 추가적인 매개변수)
    def __init__(self, name, kor, math):
        self.name = name
        self.kor = kor
        self.math = math
    
    def get_sum(self):
        return self.kor + self.math
        
student_1 = Student('홍길동',90, 80)#클래스명()->생성자, 하나의 instance생성
print("{}: {}, {}, 총점 : {}".format(student_1.name,student_1.kor,
                                  student_1.math,student_1.get_sum()) )
# Out:
# 홍길동: 90, 80, 총점 : 170

# %%
class Mate:
    def __init__(self, name, kor, eng, math):
        self.name=name
        self.kor=kor
        self.eng=eng
        self.math=math
    
    def get_sum(self):
        return self.kor + self.eng + self.math
    
    def get_avg(self):
        return self.get_sum/3

# %%
def input_data():
    name = input
mates = []
while True:
    input_data=input("이름,국어점수,영어점수,수학점수를 입력").split()
    if input_data[0] == "q":
        break
    if len(input_data) ==4:
        mates.append(Mate(input_data[0],int(input_data[1]),int(input_data[2]),\
                      int(input_data[3])))
# mates = [Mate(),Mate(),Mate(),Mate(),Mate(),Mate()]
for student in mates:
    print(student.name, )
print("이름","국어","영어","수학","총합","평균",sep="\t")

print("{}\t{}\t{}\t{}\t{}\t{}\t".format())
# Out:
# 이름,국어점수,영어점수,수학점수를 입력q
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1696/1226321093.py in <module>
#      19         mate = Mate(input_data[0],int(input_data[1]),int(input_data[2]),\
#      20                       int(input_data[3]))
# ---> 21 mates = [Mate(),Mate(),Mate(),Mate(),Mate(),Mate()]
#      22 print("이름","국어","영어","수학","총합","평균",sep="\t")
#      23
#
# TypeError: __init__() missing 4 required positional arguments: 'name', 'kor', 'eng', and 'math'
